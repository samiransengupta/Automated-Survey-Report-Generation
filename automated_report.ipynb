# %%
import pandas as pd

import numpy as np

# %%
df = pd.read_excel(r"C:\Users\samir\Desktop\webportfolio\project_automated_report_data.xlsx")

# %%
df
# Out:
#       ac_id            ac_name ward_name register_voter_status  \
# 0       123  AC -123 XXX (GEN)     XXX_2                   Yes
# 1       123  AC -123 XXX (GEN)     XXX_2                   Yes
# 2       123  AC -123 XXX (GEN)     XXX_2                   Yes
# 3       123  AC -123 XXX (GEN)     XXX_2                   Yes
# 4       123  AC -123 XXX (GEN)     XXX_2                   Yes
# ...     ...                ...       ...                   ...
# 3528    123  AC -123 XXX (GEN)     XXX_3                   Yes
# 3529    123  AC -123 XXX (GEN)     XXX_3                   Yes
# 3530    123  AC -123 XXX (GEN)     XXX_3                   Yes
# 3531    123  AC -123 XXX (GEN)     XXX_3                   Yes
# 3532    123  AC -123 XXX (GEN)     XXX_3                   Yes
#
#                                 imp_issue performance_central_gov  \
# 0                               No issues               Satisfied
# 1            Unemployment/ Job For Locals           Not Satisfied
# ...

# %%
## Sample Description

# %%
df.columns
# Out:
# Index(['ac_id', 'ac_name', 'ward_name', 'register_voter_status', 'imp_issue',
#        'performance_central_gov', 'MP_change_status', 'next_mp', 'gender',
#        'age_label', 'first_time_voter_label', 'religious_status',
#        'reservation_status', 'mothertoung', 'education_status',
#        'occupation_status', 'income_status'],
#       dtype='object')

# %%
gender = df['gender'].value_counts(normalize=True).to_frame()*100

gender
# Out:
#         proportion
# gender
# Male     74.271158
# Female   25.728842

# %%
gender.loc['Grand Total'] = gender.sum()

gender
# Out:
#              proportion
# gender
# Male          74.271158
# Female        25.728842
# Grand Total  100.000000

# %%
gender.reset_index(inplace=True)

gender
# Out:
#         gender  proportion
# 0         Male   74.271158
# 1       Female   25.728842
# 2  Grand Total  100.000000

# %%
gender.rename(columns = {'proportion':'Percentage(%)'}, inplace = True)

gender
# Out:
#         gender  Percentage(%)
# 0         Male      74.271158
# 1       Female      25.728842
# 2  Grand Total     100.000000

# %%
gender['Percentage(%)'] = gender['Percentage(%)'].apply(lambda x: '{0:.2f}'.format(x))

gender
# Out:
#         gender Percentage(%)
# 0         Male         74.27
# 1       Female         25.73
# 2  Grand Total        100.00

# %%
gender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         3 non-null      object
#  1   Percentage(%)  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes

# %%
# generating sample description function

def sample_description(data,column_name):
    results = data[column_name].value_counts(normalize = True).to_frame()*100
    results.loc['Grand Total'] = results.sum(axis = 0)
    results.reset_index(inplace=True)
    results.rename(columns = {'proportion':'Percentage(%)'}, inplace = True)
    results['Percentage(%)'] = results['Percentage(%)'].apply(lambda x: '{0:.2f}'.format(x))
    return results

# %%
gender = sample_description(df,'gender')

gender
# Out:
#         gender Percentage(%)
# 0         Male         74.27
# 1       Female         25.73
# 2  Grand Total        100.00

# %%
age = sample_description(df,'age_label')

age
# Out:
#         age_label Percentage(%)
# 0     26-45 Years         45.80
# 1     46-60 Years         28.22
# 2  Above 60 Years         15.91
# 3     18-25 Years         10.08
# 4     Grand Total        100.00

# %%
religion = sample_description(df,'religious_status')

religion
# Out:
#   religious_status Percentage(%)
# 0           Muslim         52.93
# 1            Hindu         45.57
# 2             Jain          1.25
# 3        Christian          0.11
# 4             Sikh          0.08
# 5         Buddhist          0.06
# 6      Grand Total        100.00

# %%
caste = sample_description(df, 'reservation_status')

caste
# Out:
#       reservation_status Percentage(%)
# 0                General         44.78
# 1                    OBC         37.48
# 2                     SC          9.37
# 3  Don't know/ Can't say          7.93
# 4                     ST          0.45
# 5            Grand Total        100.00

# %%
education = sample_description(df,'education_status')

education
# Out:
#           education_status Percentage(%)
# 0  Attended Primary School         25.53
# 1               Illiterate         24.00
# 2           Up to Class 10         20.21
# 3                 Graduate         14.07
# 4           Up to Class 12         13.84
# 5    Post Graduate & Above          2.35
# 6              Grand Total        100.00

# %%
occupation = sample_description(df, 'occupation_status')

occupation
# Out:
#                 occupation_status Percentage(%)
# 0   Self-employed/ Small Business         39.40
# 1                       Housewife         17.49
# 2             Daily Wage Labourer         15.34
# 3         Private Sector Employee         10.64
# 4                      Unemployed          9.26
# 5       Professional / Consultant          3.06
# 6             Government Employee          1.81
# 7                          Others          1.64
# 8                         Student          1.16
# 9                          Farmer          0.20
# 10                    Grand Total        100.00

# %%
income = sample_description(df,'income_status')

income
# Out:
#          income_status Percentage(%)
# 0   Less than Rs 10000         42.88
# 1     Rs 10000 - 20000         36.26
# 2     Rs 21000 - 30000         13.76
# 3     Rs 31000 - 50000          5.35
# 4     Rs 51000 - 99000          0.91
# 5   Rs 1 Lakh - 2 Lakh          0.65
# 6  More than Rs 2 Lakh          0.20
# 7          Grand Total        100.00

# %%
df.head(3)
# Out:
#    ac_id            ac_name ward_name register_voter_status  \
# 0    123  AC -123 XXX (GEN)     XXX_2                   Yes
# 1    123  AC -123 XXX (GEN)     XXX_2                   Yes
# 2    123  AC -123 XXX (GEN)     XXX_2                   Yes
#
#                       imp_issue performance_central_gov MP_change_status  \
# 0                     No issues               Satisfied           Change
# 1  Unemployment/ Job For Locals           Not Satisfied           Change
# 2  Unemployment/ Job For Locals           Not Satisfied           Change
#
#                  next_mp gender    age_label first_time_voter_label  \
# 0  Don't know/ Can't say   Male  26-45 Years                     No
# 1                    AAA   Male  26-45 Years                     No
# 2                    AAA   Male  26-45 Years                     No
#
#   religious_status reservation_status mothertoung education_status  \
# 0            Hindu            General       Hindi   Up to Class 12
# ...

# %%
gender_wise = pd.crosstab(df['performance_central_gov'],df['gender'],normalize='columns')

gender_wise.sort_values(by='Female',ascending=False, inplace = True)

gender_wise = gender_wise[['Female','Male']]*100

gender_wise.loc['Grand Total'] = gender_wise.sum(axis = 0)

gender_wise[["Female", "Male"]] = gender_wise[["Female", "Male"]].applymap(lambda x: '{:.2f}'.format(x))

gender_wise.reset_index(inplace= True)

gender_wise.rename(columns = {'performance_central_gov':'Opinion','Female':'Female(%)','Male':'Male(%)'}, inplace=True)


gender_wise
# Out:
# gender                Opinion Female(%) Male(%)
# 0                   Satisfied     58.75   43.37
# 1               Not Satisfied     38.06   53.77
# 2       Don't know/ Can't say      3.19    2.86
# 3                 Grand Total    100.00  100.00

# %%
# generating voting intention fuction

def cross_tab_by_variables(column_1,column_2):
    crosstab_result = pd.crosstab(df[column_1],df[column_2],normalize = 'columns')
    crosstab_result = crosstab_result*100
    crosstab_result.loc['Grand Total'] = crosstab_result.sum(axis=0)
    crosstab_result = crosstab_result.applymap(lambda x: '{:.2f}'.format(x))
    crosstab_result.reset_index(inplace=True)
    
    new_column_names = {column_1:'Opinion'}
    
    for col in crosstab_result.columns[1:]:
        new_column_names[col] = f'{col} (%)'
        
    crosstab_result.rename(columns=new_column_names, inplace=True)
    
    first_percentage_col = crosstab_result.columns[1]

    
    return crosstab_result

# %%
age_wise = cross_tab_by_variables('performance_central_gov','age_label')

age_wise
# Out:
# age_label                Opinion 18-25 Years (%) 26-45 Years (%)  \
# 0          Don't know/ Can't say            2.53            2.90
# 1                  Not Satisfied           62.08           51.30
# 2                      Satisfied           35.39           45.80
# 3                    Grand Total          100.00          100.00
#
# age_label 46-60 Years (%) Above 60 Years (%)
# 0                    3.01               3.20
# 1                   46.54              43.06
# 2                   50.45              53.74
# 3                  100.00             100.00

# %%
gender_wise = cross_tab_by_variables('performance_central_gov','gender')

gender_wise
# Out:
# gender                Opinion Female (%) Male (%)
# 0       Don't know/ Can't say       3.19     2.86
# 1               Not Satisfied      38.06    53.77
# 2                   Satisfied      58.75    43.37
# 3                 Grand Total     100.00   100.00

# %%
religion_wise = cross_tab_by_variables('performance_central_gov','religious_status')

religion_wise
# Out:
# religious_status                Opinion Buddhist (%) Christian (%) Hindu (%)  \
# 0                 Don't know/ Can't say        50.00          0.00      1.99
# 1                         Not Satisfied         0.00         75.00     19.19
# 2                             Satisfied        50.00         25.00     78.82
# 3                           Grand Total       100.00        100.00    100.00
#
# religious_status Jain (%) Muslim (%) Sikh (%)
# 0                    2.27       3.74     0.00
# 1                   20.45      76.74    33.33
# 2                   77.27      19.52    66.67
# 3                  100.00     100.00   100.00

# %%
caste_wise = cross_tab_by_variables('performance_central_gov','reservation_status')

caste_wise = caste_wise.iloc[:,[0,2,3,4,5]]

caste_wise
# Out:
# reservation_status                Opinion General (%) OBC (%)  SC (%)  ST (%)
# 0                   Don't know/ Can't say        2.72    3.47    3.32    6.25
# 1                           Not Satisfied       46.40   60.95   23.26   50.00
# 2                               Satisfied       50.88   35.57   73.41   43.75
# 3                             Grand Total      100.00  100.00  100.00  100.00

# %%
education_wise = cross_tab_by_variables('performance_central_gov','education_status')

education_wise
# Out:
# education_status                Opinion Attended Primary School (%)  \
# 0                 Don't know/ Can't say                        2.33
# 1                         Not Satisfied                       52.44
# 2                             Satisfied                       45.23
# 3                           Grand Total                      100.00
#
# education_status Graduate (%) Illiterate (%) Post Graduate & Above (%)  \
# 0                        2.21           5.78                      2.41
# 1                       43.46          53.07                     40.96
# 2                       54.33          41.16                     56.63
# 3                      100.00         100.00                    100.00
#
# education_status Up to Class 10 (%) Up to Class 12 (%)
# 0                              1.82               1.64
# 1                             50.84              45.19
# 2                             47.34              53.17
# ...

# %%
occupation_wise = cross_tab_by_variables('performance_central_gov','occupation_status')

occupation_wise
# Out:
# occupation_status                Opinion Daily Wage Labourer (%) Farmer (%)  \
# 0                  Don't know/ Can't say                    5.35       0.00
# 1                          Not Satisfied                   61.25      42.86
# 2                              Satisfied                   33.39      57.14
# 3                            Grand Total                  100.00     100.00
#
# occupation_status Government Employee (%) Housewife (%) Others (%)  \
# 0                                    1.56          2.91       8.62
# 1                                   20.31         36.89      53.45
# 2                                   78.12         60.19      37.93
# 3                                  100.00        100.00     100.00
#
# occupation_status Private Sector Employee (%) Professional / Consultant (%)  \
# 0                                        1.86                          1.85
# 1                                       48.67                         48.15
# ...

# %%
income_wise = cross_tab_by_variables('performance_central_gov','income_status')

income_wise
# Out:
# income_status                Opinion Less than Rs 10000 (%)  \
# 0              Don't know/ Can't say                   4.29
# 1                      Not Satisfied                  53.07
# 2                          Satisfied                  42.64
# 3                        Grand Total                 100.00
#
# income_status More than Rs 2 Lakh (%) Rs 1 Lakh - 2 Lakh (%)  \
# 0                               14.29                   4.35
# 1                               42.86                  47.83
# 2                               42.86                  47.83
# 3                              100.00                 100.00
#
# income_status Rs 10000 - 20000 (%) Rs 21000 - 30000 (%) Rs 31000 - 50000 (%)  \
# 0                             2.26                 1.03                 1.06
# 1                            49.96                41.36                46.03
# 2                            47.78                57.61                52.91
# ...

# %%
# important issues

imp_issue = sample_description(df,'imp_issue')

imp_issue
# Out:
#                                             imp_issue Percentage(%)
# 0                        Unemployment/ Job For Locals         40.16
# 1                               Inflation/ Price Rise         21.20
# 2                                           No issues         17.41
# 3                 Sanitation/ Drainage / Water Supply          4.44
# 4                                 Lack of Development          3.06
# 5                                          Corruption          2.38
# 6                         Hindu/ Muslim - Communalism          1.64
# 7                               Don't know/ Can't say          1.39
# 8                                              Others          1.33
# 9                           Electricity/ Power Tariff          1.05
# 10              School/ College/ University Education          0.93
# 11                              Roads/ Transportation          0.88
# 12                                      Law and Order          0.76
# ...

# %%
# overall voting intention

performace = sample_description(df,'performance_central_gov')

performace
# Out:
#   performance_central_gov Percentage(%)
# 0           Not Satisfied         49.73
# 1               Satisfied         47.33
# 2   Don't know/ Can't say          2.94
# 3             Grand Total        100.00

# %%
df.columns
# Out:
# Index(['ac_id', 'ac_name', 'ward_name', 'register_voter_status', 'imp_issue',
#        'performance_central_gov', 'MP_change_status', 'next_mp', 'gender',
#        'age_label', 'first_time_voter_label', 'religious_status',
#        'reservation_status', 'mothertoung', 'education_status',
#        'occupation_status', 'income_status'],
#       dtype='object')

# %%
df['ac_name']
# Out:
# 0       AC -123 XXX (GEN)
# 1       AC -123 XXX (GEN)
# 2       AC -123 XXX (GEN)
# 3       AC -123 XXX (GEN)
# 4       AC -123 XXX (GEN)
#               ...
# 3528    AC -123 XXX (GEN)
# 3529    AC -123 XXX (GEN)
# 3530    AC -123 XXX (GEN)
# 3531    AC -123 XXX (GEN)
# 3532    AC -123 XXX (GEN)
# Name: ac_name, Length: 3533, dtype: object

# %%
# data tables to word template

# %%
# Imports the Document class from the python-docx library.
from docx import Document

# Imports Mm for measurement
from docx.shared import Mm

# %%
# for text alignment
from docx.enum.text import WD_ALIGN_PARAGRAPH

# %%
# for styling the word documet
from docx.oxml.ns import nsdecls
from docx.oxml import parse_xml

# %%
doc = Document('blank_template.docx') # uploading blank template for reports

# %%
# Sample break up

# %%
# gender 

doc.add_paragraph('Chapter 1 – Sample Break up','Heading 1')
doc.add_paragraph('Table 1.1: Gender wise break up', 'Heading 2')

columns = list(gender.columns) # get columns list

table = doc.add_table(rows=1, cols=len(columns),style='Table Grid') # add table with 1 row and len(columns) columns
table.autofit = True # set autofit true

for col in range(len(columns)):
    #set_cell_margins(table.cell(0, col), top=100, start=100, bottom=100, end=50) # set cell margin
    table.cell(0, col).text = columns[col]
    
# iterate on dataframe  

for i, row in enumerate(gender.itertuples()):
    table_row = table.add_row().cells           # add new row to table
    for col in range(len(columns)):             # iterate over each column in row and add text
        table_row[col].text = str(row[col+1]) # avoid index by adding col+1

# %%
# gender styling
for col in range(len(columns)):
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(0)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
last_row_idx = len(table.rows) - 1  # Index of the last row
for col in range(len(columns)):  # Iterate over all columns in the last row
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(last_row_idx)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
# Bold & center first row 
for col in range(len(columns)):
    table.cell(0, col).paragraphs[0].runs[0].font.bold = True
    table.cell(0, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER

# Bold & center last row
for col in range(len(columns)):
    table.cell(len(table.rows) - 1, col).paragraphs[0].runs[0].font.bold = True
    table.cell(len(table.rows) - 1, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER
    

# Center align all other cells
for row in table.rows[1:-1]:  # Excluding the first and last rows
    for cell in row.cells:
        for paragraph in cell.paragraphs:
            paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER
            
# Left align the strings in the first column
for row in table.rows:
    row.cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.LEFT

# %%
doc.add_paragraph('') # adding blank space

# %%
# age 

doc.add_paragraph('Table 1.2: Age wise break up', 'Heading 2')

columns = list(age.columns) # get columns list

table = doc.add_table(rows=1, cols=len(columns),style='Table Grid') # add table with 1 row and len(columns) columns
table.autofit = True # set autofit true

for col in range(len(columns)):
    #set_cell_margins(table.cell(0, col), top=100, start=100, bottom=100, end=50) # set cell margin
    table.cell(0, col).text = columns[col]
    
# iterate on dataframe  

for i, row in enumerate(age.itertuples()):
    table_row = table.add_row().cells           # add new row to table
    for col in range(len(columns)):             # iterate over each column in row and add text
        table_row[col].text = str(row[col+1]) # avoid index by adding col+1

# %%
# age styling

for col in range(len(columns)):
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(0)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
last_row_idx = len(table.rows) - 1  # Index of the last row
for col in range(len(columns)):  # Iterate over all columns in the last row
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(last_row_idx)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
# Bold & center first row 
for col in range(len(columns)):
    table.cell(0, col).paragraphs[0].runs[0].font.bold = True
    table.cell(0, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER

# Bold & center last row
for col in range(len(columns)):
    table.cell(len(table.rows) - 1, col).paragraphs[0].runs[0].font.bold = True
    table.cell(len(table.rows) - 1, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER
    

# Center align all other cells
for row in table.rows[1:-1]:  # Excluding the first and last rows
    for cell in row.cells:
        for paragraph in cell.paragraphs:
            paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER
            
# Left align the strings in the first column
for row in table.rows:
    row.cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.LEFT

# %%
doc.add_paragraph('') # adding blank space

# %%
# religion wise break up

doc.add_paragraph('Table 1.3: Religion wise break up', 'Heading 2')

columns = list(religion.columns) # get columns list

table = doc.add_table(rows=1, cols=len(columns),style='Table Grid') # add table with 1 row and len(columns) columns
table.autofit = True # set autofit true

for col in range(len(columns)):
    #set_cell_margins(table.cell(0, col), top=100, start=100, bottom=100, end=50) # set cell margin
    table.cell(0, col).text = columns[col]
    
# iterate on dataframe  

for i, row in enumerate(religion.itertuples()):
    table_row = table.add_row().cells           # add new row to table
    for col in range(len(columns)):             # iterate over each column in row and add text
        table_row[col].text = str(row[col+1]) # avoid index by adding col+1

# %%
# religion styling

for col in range(len(columns)):
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(0)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
last_row_idx = len(table.rows) - 1  # Index of the last row
for col in range(len(columns)):  # Iterate over all columns in the last row
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(last_row_idx)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
# Bold & center first row 
for col in range(len(columns)):
    table.cell(0, col).paragraphs[0].runs[0].font.bold = True
    table.cell(0, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER

# Bold & center last row
for col in range(len(columns)):
    table.cell(len(table.rows) - 1, col).paragraphs[0].runs[0].font.bold = True
    table.cell(len(table.rows) - 1, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER
    

# Center align all other cells
for row in table.rows[1:-1]:  # Excluding the first and last rows
    for cell in row.cells:
        for paragraph in cell.paragraphs:
            paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER
            
# Left align the strings in the first column
for row in table.rows:
    row.cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.LEFT

# %%
doc.add_paragraph('') # adding blank space

# %%
# caste wise break up

doc.add_paragraph('Table 1.4: Caste wise break up', 'Heading 2')

columns = list(caste.columns) # get columns list

table = doc.add_table(rows=1, cols=len(columns),style='Table Grid') # add table with 1 row and len(columns) columns
table.autofit = True # set autofit true

for col in range(len(columns)):
    #set_cell_margins(table.cell(0, col), top=100, start=100, bottom=100, end=50) # set cell margin
    table.cell(0, col).text = columns[col]
    
# iterate on dataframe  

for i, row in enumerate(caste.itertuples()):
    table_row = table.add_row().cells           # add new row to table
    for col in range(len(columns)):             # iterate over each column in row and add text
        table_row[col].text = str(row[col+1]) # avoid index by adding col+1

# %%
# caste styling

for col in range(len(columns)):
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(0)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
last_row_idx = len(table.rows) - 1  # Index of the last row
for col in range(len(columns)):  # Iterate over all columns in the last row
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(last_row_idx)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
# Bold & center first row 
for col in range(len(columns)):
    table.cell(0, col).paragraphs[0].runs[0].font.bold = True
    table.cell(0, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER

# Bold & center last row
for col in range(len(columns)):
    table.cell(len(table.rows) - 1, col).paragraphs[0].runs[0].font.bold = True
    table.cell(len(table.rows) - 1, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER
    

# Center align all other cells
for row in table.rows[1:-1]:  # Excluding the first and last rows
    for cell in row.cells:
        for paragraph in cell.paragraphs:
            paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER
            
# Left align the strings in the first column
for row in table.rows:
    row.cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.LEFT

# %%
doc.add_paragraph('') # adding blank space

# %%
# education wise break up

doc.add_paragraph('Table 1.5: Education wise break up', 'Heading 2')

columns = list(education.columns) # get columns list

table = doc.add_table(rows=1, cols=len(columns),style='Table Grid') # add table with 1 row and len(columns) columns
table.autofit = True # set autofit true

for col in range(len(columns)):
    #set_cell_margins(table.cell(0, col), top=100, start=100, bottom=100, end=50) # set cell margin
    table.cell(0, col).text = columns[col]
    
# iterate on dataframe  

for i, row in enumerate(education.itertuples()):
    table_row = table.add_row().cells           # add new row to table
    for col in range(len(columns)):             # iterate over each column in row and add text
        table_row[col].text = str(row[col+1]) # avoid index by adding col+1

# %%
# education styling

for col in range(len(columns)):
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(0)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
last_row_idx = len(table.rows) - 1  # Index of the last row
for col in range(len(columns)):  # Iterate over all columns in the last row
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(last_row_idx)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
# Bold & center first row 
for col in range(len(columns)):
    table.cell(0, col).paragraphs[0].runs[0].font.bold = True
    table.cell(0, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER

# Bold & center last row
for col in range(len(columns)):
    table.cell(len(table.rows) - 1, col).paragraphs[0].runs[0].font.bold = True
    table.cell(len(table.rows) - 1, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER
    

# Center align all other cells
for row in table.rows[1:-1]:  # Excluding the first and last rows
    for cell in row.cells:
        for paragraph in cell.paragraphs:
            paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER
            
# Left align the strings in the first column
for row in table.rows:
    row.cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.LEFT

# %%
doc.add_paragraph('') # adding blank space

# %%
# occupation wise break up

doc.add_paragraph('Table 1.6: Occupation wise break up', 'Heading 2')

columns = list(occupation.columns) # get columns list

table = doc.add_table(rows=1, cols=len(columns),style='Table Grid') # add table with 1 row and len(columns) columns
table.autofit = True # set autofit true

for col in range(len(columns)):
    #set_cell_margins(table.cell(0, col), top=100, start=100, bottom=100, end=50) # set cell margin
    table.cell(0, col).text = columns[col]
    
# iterate on dataframe  

for i, row in enumerate(occupation.itertuples()):
    table_row = table.add_row().cells           # add new row to table
    for col in range(len(columns)):             # iterate over each column in row and add text
        table_row[col].text = str(row[col+1]) # avoid index by adding col+1

# %%
# occupation styling

for col in range(len(columns)):
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(0)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
last_row_idx = len(table.rows) - 1  # Index of the last row
for col in range(len(columns)):  # Iterate over all columns in the last row
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(last_row_idx)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
# Bold & center first row 
for col in range(len(columns)):
    table.cell(0, col).paragraphs[0].runs[0].font.bold = True
    table.cell(0, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER

# Bold & center last row
for col in range(len(columns)):
    table.cell(len(table.rows) - 1, col).paragraphs[0].runs[0].font.bold = True
    table.cell(len(table.rows) - 1, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER
    

# Center align all other cells
for row in table.rows[1:-1]:  # Excluding the first and last rows
    for cell in row.cells:
        for paragraph in cell.paragraphs:
            paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER
            
# Left align the strings in the first column
for row in table.rows:
    row.cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.LEFT

# %%
doc.add_paragraph('') # adding blank space

# %%
# income wise break up

doc.add_paragraph('Table 1.7: Income wise break up', 'Heading 2')

columns = list(income.columns) # get columns list

table = doc.add_table(rows=1, cols=len(columns),style='Table Grid') # add table with 1 row and len(columns) columns
table.autofit = True # set autofit true

for col in range(len(columns)):
    #set_cell_margins(table.cell(0, col), top=100, start=100, bottom=100, end=50) # set cell margin
    table.cell(0, col).text = columns[col]
    
# iterate on dataframe  

for i, row in enumerate(income.itertuples()):
    table_row = table.add_row().cells           # add new row to table
    for col in range(len(columns)):             # iterate over each column in row and add text
        table_row[col].text = str(row[col+1]) # avoid index by adding col+1

# %%
# income styling

for col in range(len(columns)):
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(0)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
last_row_idx = len(table.rows) - 1  # Index of the last row
for col in range(len(columns)):  # Iterate over all columns in the last row
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(last_row_idx)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
# Bold & center first row 
for col in range(len(columns)):
    table.cell(0, col).paragraphs[0].runs[0].font.bold = True
    table.cell(0, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER

# Bold & center last row
for col in range(len(columns)):
    table.cell(len(table.rows) - 1, col).paragraphs[0].runs[0].font.bold = True
    table.cell(len(table.rows) - 1, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER
    

# Center align all other cells
for row in table.rows[1:-1]:  # Excluding the first and last rows
    for cell in row.cells:
        for paragraph in cell.paragraphs:
            paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER
            
# Left align the strings in the first column
for row in table.rows:
    row.cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.LEFT

# %%
doc.add_page_break() # adding page break

# %%
# overall and category wise voting intention - chapter 2

# %%
# performance general 

doc.add_paragraph('Chapter 2 – Voting Intentions','Heading 1')
doc.add_paragraph('Table 2.1: Q - Are you satisfied with the performance of the BJP-led NDA Government at the Centre?', 'Heading 2')

columns = list(performace.columns) # get columns list

table = doc.add_table(rows=1, cols=len(columns),style='Table Grid') # add table with 1 row and len(columns) columns
table.autofit = True # set autofit true

for col in range(len(columns)):
    #set_cell_margins(table.cell(0, col), top=100, start=100, bottom=100, end=50) # set cell margin
    table.cell(0, col).text = columns[col]
    
# iterate on dataframe  

for i, row in enumerate(performace.itertuples()):
    table_row = table.add_row().cells           # add new row to table
    for col in range(len(columns)):             # iterate over each column in row and add text
        table_row[col].text = str(row[col+1]) # avoid index by adding col+1

# %%
# performance styling

for col in range(len(columns)):
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(0)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
last_row_idx = len(table.rows) - 1  # Index of the last row
for col in range(len(columns)):  # Iterate over all columns in the last row
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(last_row_idx)[col]._tc.get_or_add_tcPr().append(shading_elm_1)

# Bold & center first row 
for col in range(len(columns)):
    table.cell(0, col).paragraphs[0].runs[0].font.bold = True
    table.cell(0, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER

# Bold & center last row
for col in range(len(columns)):
    table.cell(len(table.rows) - 1, col).paragraphs[0].runs[0].font.bold = True
    table.cell(len(table.rows) - 1, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER
    

# Center align all other cells
for row in table.rows[1:-1]:  # Excluding the first and last rows
    for cell in row.cells:
        for paragraph in cell.paragraphs:
            paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER
            
# Left align the strings in the first column
for row in table.rows:
    row.cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.LEFT

# %%
doc.add_paragraph('') # adding blank space

# %%
# gender wise 

doc.add_paragraph('Table 2.2: Gender wise Voting Intentions', 'Heading 2')

columns = list(gender_wise.columns) # get columns list

table = doc.add_table(rows=1, cols=len(columns),style='Table Grid') # add table with 1 row and len(columns) columns
table.autofit = True # set autofit true

for col in range(len(columns)):
    #set_cell_margins(table.cell(0, col), top=100, start=100, bottom=100, end=50) # set cell margin
    table.cell(0, col).text = columns[col]
    
# iterate on dataframe  

for i, row in enumerate(gender_wise.itertuples()):
    table_row = table.add_row().cells           # add new row to table
    for col in range(len(columns)):             # iterate over each column in row and add text
        table_row[col].text = str(row[col+1]) # avoid index by adding col+1

# %%
# gender styling

for col in range(len(columns)):
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(0)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
last_row_idx = len(table.rows) - 1  # Index of the last row
for col in range(len(columns)):  # Iterate over all columns in the last row
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(last_row_idx)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
# Bold & center first row 
for col in range(len(columns)):
    table.cell(0, col).paragraphs[0].runs[0].font.bold = True
    table.cell(0, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER

# Bold & center last row
for col in range(len(columns)):
    table.cell(len(table.rows) - 1, col).paragraphs[0].runs[0].font.bold = True
    table.cell(len(table.rows) - 1, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER
    

# Center align all other cells
for row in table.rows[1:-1]:  # Excluding the first and last rows
    for cell in row.cells:
        for paragraph in cell.paragraphs:
            paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER
            
# Left align the strings in the first column
for row in table.rows:
    row.cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.LEFT

# %%
doc.add_paragraph('') # adding blank space

# %%
# age wise

doc.add_paragraph('Table 2.3: Age cohort wise Voting Intentions', 'Heading 2')

columns = list(age_wise.columns) # get columns list

table = doc.add_table(rows=1, cols=len(columns),style='Table Grid') # add table with 1 row and len(columns) columns
table.autofit = True # set autofit true

for col in range(len(columns)):
    #set_cell_margins(table.cell(0, col), top=100, start=100, bottom=100, end=50) # set cell margin
    table.cell(0, col).text = columns[col]
    
# iterate on dataframe  

for i, row in enumerate(age_wise.itertuples()):
    table_row = table.add_row().cells           # add new row to table
    for col in range(len(columns)):             # iterate over each column in row and add text
        table_row[col].text = str(row[col+1]) # avoid index by adding col+1

# %%
# age wise styling

for col in range(len(columns)):
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(0)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
last_row_idx = len(table.rows) - 1  # Index of the last row
for col in range(len(columns)):  # Iterate over all columns in the last row
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(last_row_idx)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
# Bold & center first row 
for col in range(len(columns)):
    table.cell(0, col).paragraphs[0].runs[0].font.bold = True
    table.cell(0, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER

# Bold & center last row
for col in range(len(columns)):
    table.cell(len(table.rows) - 1, col).paragraphs[0].runs[0].font.bold = True
    table.cell(len(table.rows) - 1, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER
    

# Center align all other cells
for row in table.rows[1:-1]:  # Excluding the first and last rows
    for cell in row.cells:
        for paragraph in cell.paragraphs:
            paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER
            
# Left align the strings in the first column
for row in table.rows:
    row.cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.LEFT

# %%
doc.add_paragraph('') # adding blank space

# %%
# religion wise

doc.add_paragraph('Table 2.4: Religion wise Voting Intentions', 'Heading 2')

columns = list(religion_wise.columns) # get columns list

table = doc.add_table(rows=1, cols=len(columns),style='Table Grid') # add table with 1 row and len(columns) columns
table.autofit = True # set autofit true

for col in range(len(columns)):
    #set_cell_margins(table.cell(0, col), top=100, start=100, bottom=100, end=50) # set cell margin
    table.cell(0, col).text = columns[col]
    
# iterate on dataframe  

for i, row in enumerate(religion_wise.itertuples()):
    table_row = table.add_row().cells           # add new row to table
    for col in range(len(columns)):             # iterate over each column in row and add text
        table_row[col].text = str(row[col+1]) # avoid index by adding col+1

# %%
# religion wise styling

for col in range(len(columns)):
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(0)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
last_row_idx = len(table.rows) - 1  # Index of the last row
for col in range(len(columns)):  # Iterate over all columns in the last row
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(last_row_idx)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
# Bold & center first row 
for col in range(len(columns)):
    table.cell(0, col).paragraphs[0].runs[0].font.bold = True
    table.cell(0, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER

# Bold & center last row
for col in range(len(columns)):
    table.cell(len(table.rows) - 1, col).paragraphs[0].runs[0].font.bold = True
    table.cell(len(table.rows) - 1, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER
    

# Center align all other cells
for row in table.rows[1:-1]:  # Excluding the first and last rows
    for cell in row.cells:
        for paragraph in cell.paragraphs:
            paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER
            
# Left align the strings in the first column
for row in table.rows:
    row.cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.LEFT

# %%
doc.add_paragraph('') # adding blank space

# %%
# caste wise

doc.add_paragraph('Table 2.5: Caste wise Voting Intentions', 'Heading 2')

columns = list(caste_wise.columns) # get columns list

table = doc.add_table(rows=1, cols=len(columns),style='Table Grid') # add table with 1 row and len(columns) columns
table.autofit = True # set autofit true

for col in range(len(columns)):
    #set_cell_margins(table.cell(0, col), top=100, start=100, bottom=100, end=50) # set cell margin
    table.cell(0, col).text = columns[col]
    
# iterate on dataframe  

for i, row in enumerate(caste_wise.itertuples()):
    table_row = table.add_row().cells           # add new row to table
    for col in range(len(columns)):             # iterate over each column in row and add text
        table_row[col].text = str(row[col+1]) # avoid index by adding col+1

# %%
# caste wise styling

for col in range(len(columns)):
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(0)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
last_row_idx = len(table.rows) - 1  # Index of the last row
for col in range(len(columns)):  # Iterate over all columns in the last row
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(last_row_idx)[col]._tc.get_or_add_tcPr().append(shading_elm_1)

# Bold & center first row 
for col in range(len(columns)):
    table.cell(0, col).paragraphs[0].runs[0].font.bold = True
    table.cell(0, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER

# Bold & center last row
for col in range(len(columns)):
    table.cell(len(table.rows) - 1, col).paragraphs[0].runs[0].font.bold = True
    table.cell(len(table.rows) - 1, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER
    

# Center align all other cells
for row in table.rows[1:-1]:  # Excluding the first and last rows
    for cell in row.cells:
        for paragraph in cell.paragraphs:
            paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER
            
# Left align the strings in the first column
for row in table.rows:
    row.cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.LEFT

# %%
doc.add_paragraph('') # adding blank space

# %%
# education wise

doc.add_paragraph('Table 2.6: Education level wise Voting Intentions', 'Heading 2')

columns = list(education_wise.columns) # get columns list

table = doc.add_table(rows=1, cols=len(columns),style='Table Grid') # add table with 1 row and len(columns) columns
table.autofit = True # set autofit true

for col in range(len(columns)):
    #set_cell_margins(table.cell(0, col), top=100, start=100, bottom=100, end=50) # set cell margin
    table.cell(0, col).text = columns[col]
    
# iterate on dataframe  

for i, row in enumerate(education_wise.itertuples()):
    table_row = table.add_row().cells           # add new row to table
    for col in range(len(columns)):             # iterate over each column in row and add text
        table_row[col].text = str(row[col+1]) # avoid index by adding col+1

# %%
# education wise styling

for col in range(len(columns)):
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(0)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
last_row_idx = len(table.rows) - 1  # Index of the last row
for col in range(len(columns)):  # Iterate over all columns in the last row
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(last_row_idx)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
# Bold & center first row 
for col in range(len(columns)):
    table.cell(0, col).paragraphs[0].runs[0].font.bold = True
    table.cell(0, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER

# Bold & center last row
for col in range(len(columns)):
    table.cell(len(table.rows) - 1, col).paragraphs[0].runs[0].font.bold = True
    table.cell(len(table.rows) - 1, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER
    

# Center align all other cells
for row in table.rows[1:-1]:  # Excluding the first and last rows
    for cell in row.cells:
        for paragraph in cell.paragraphs:
            paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER
            
# Left align the strings in the first column
for row in table.rows:
    row.cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.LEFT

# %%
doc.add_paragraph('') # adding blank space

# %%
# occupation wise

doc.add_paragraph('Table 2.7: Occupation wise Voting Intentions', 'Heading 2')

columns = list(occupation_wise.columns) # get columns list

table = doc.add_table(rows=1, cols=len(columns),style='Table Grid') # add table with 1 row and len(columns) columns
table.autofit = True # set autofit true

for col in range(len(columns)):
    #set_cell_margins(table.cell(0, col), top=100, start=100, bottom=100, end=50) # set cell margin
    table.cell(0, col).text = columns[col]
    
# iterate on dataframe  

for i, row in enumerate(occupation_wise.itertuples()):
    table_row = table.add_row().cells           # add new row to table
    for col in range(len(columns)):             # iterate over each column in row and add text
        table_row[col].text = str(row[col+1]) # avoid index by adding col+1

# %%
# occupation wise styling

for col in range(len(columns)):
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(0)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
last_row_idx = len(table.rows) - 1  # Index of the last row
for col in range(len(columns)):  # Iterate over all columns in the last row
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(last_row_idx)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
# Bold & center first row 
for col in range(len(columns)):
    table.cell(0, col).paragraphs[0].runs[0].font.bold = True
    table.cell(0, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER

# Bold & center last row
for col in range(len(columns)):
    table.cell(len(table.rows) - 1, col).paragraphs[0].runs[0].font.bold = True
    table.cell(len(table.rows) - 1, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER
    

# Center align all other cells
for row in table.rows[1:-1]:  # Excluding the first and last rows
    for cell in row.cells:
        for paragraph in cell.paragraphs:
            paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER
            
# Left align the strings in the first column
for row in table.rows:
    row.cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.LEFT

# %%
doc.add_paragraph('') # adding blank space

# %%
# income wise

doc.add_paragraph('Table 2.8: Income wise Voting Intentions', 'Heading 2')

columns = list(income_wise.columns) # get columns list

table = doc.add_table(rows=1, cols=len(columns),style='Table Grid') # add table with 1 row and len(columns) columns
table.autofit = True # set autofit true

for col in range(len(columns)):
    #set_cell_margins(table.cell(0, col), top=100, start=100, bottom=100, end=50) # set cell margin
    table.cell(0, col).text = columns[col]
    
# iterate on dataframe  

for i, row in enumerate(income_wise.itertuples()):
    table_row = table.add_row().cells           # add new row to table
    for col in range(len(columns)):             # iterate over each column in row and add text
        table_row[col].text = str(row[col+1]) # avoid index by adding col+1

# %%
# income wise styling

for col in range(len(columns)):
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(0)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
last_row_idx = len(table.rows) - 1  # Index of the last row
for col in range(len(columns)):  # Iterate over all columns in the last row
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(last_row_idx)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
# Bold & center first row 
for col in range(len(columns)):
    table.cell(0, col).paragraphs[0].runs[0].font.bold = True
    table.cell(0, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER

# Bold & center last row
for col in range(len(columns)):
    table.cell(len(table.rows) - 1, col).paragraphs[0].runs[0].font.bold = True
    table.cell(len(table.rows) - 1, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER
    

# Center align all other cells
for row in table.rows[1:-1]:  # Excluding the first and last rows
    for cell in row.cells:
        for paragraph in cell.paragraphs:
            paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER
            
# Left align the strings in the first column
for row in table.rows:
    row.cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.LEFT

# %%
doc.add_page_break() # adding page break

# %%
# chapter 3 , important issues

# %%
# imp_issue
doc.add_paragraph('Chapter 3 – Important Issues','Heading 1')
doc.add_paragraph('Table 3.1: Q - If elections are held tomorrow, what is the single most important issue/problem for you, in your day-to-day life, that will decide your vote in the upcoming Lok Sabha election?', 'Heading 2')

columns = list(imp_issue.columns) # get columns list

table = doc.add_table(rows=1, cols=len(columns),style='Table Grid') # add table with 1 row and len(columns) columns
table.autofit = True # set autofit true

for col in range(len(columns)):
    #set_cell_margins(table.cell(0, col), top=100, start=100, bottom=100, end=50) # set cell margin
    table.cell(0, col).text = columns[col]
    
# iterate on dataframe  

for i, row in enumerate(imp_issue.itertuples()):
    table_row = table.add_row().cells           # add new row to table
    for col in range(len(columns)):             # iterate over each column in row and add text
        table_row[col].text = str(row[col+1]) # avoid index by adding col+1

# %%
# imp_issue styling

for col in range(len(columns)):
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(0)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
last_row_idx = len(table.rows) - 1  # Index of the last row
for col in range(len(columns)):  # Iterate over all columns in the last row
    shading_elm_1 = parse_xml(r'<w:shd {} w:fill="#BEBEBE"/>'.format(nsdecls('w')))
    table.row_cells(last_row_idx)[col]._tc.get_or_add_tcPr().append(shading_elm_1)
    
# Bold & center first row 
for col in range(len(columns)):
    table.cell(0, col).paragraphs[0].runs[0].font.bold = True
    table.cell(0, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER

# Bold & center last row
for col in range(len(columns)):
    table.cell(len(table.rows) - 1, col).paragraphs[0].runs[0].font.bold = True
    table.cell(len(table.rows) - 1, col).paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.CENTER
    

# Center align all other cells
for row in table.rows[1:-1]:  # Excluding the first and last rows
    for cell in row.cells:
        for paragraph in cell.paragraphs:
            paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER
            
# Left align the strings in the first column
for row in table.rows:
    row.cells[0].paragraphs[0].alignment = WD_ALIGN_PARAGRAPH.LEFT

# %%
doc.save('blank_template.docx')
